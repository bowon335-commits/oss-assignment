# %% [markdown]
# <a href="https://colab.research.google.com/github/bowon335-commits/oss-assignment/blob/main/oss_%EA%B3%BC%EC%A0%9C_2545287_%EC%9D%B4%EC%A7%80%EC%9C%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

# 1. 데이터셋 로드 (운동 데이터)
linnerud = datasets.load_linnerud()
data = linnerud.data
target = linnerud.target

print(f"데이터 크기: {data.shape}")

# 2. train/test split
X_train, X_test, y_train, y_test = train_test_split(
    data, target, test_size=0.2, random_state=42
)
# Out:
# 데이터 크기: (20, 3)
# k-NN 회귀 모델 (k=4) MSE (평균 제곱 오차): 187.1250
